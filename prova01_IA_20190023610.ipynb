# %% [markdown]
# <a href="https://colab.research.google.com/github/phnss/Prova01-IA/blob/main/prova01_IA_20190023610.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PROVA IA
# ##Aluno: Pedro Henrique Nogueira da Silva Santos
# ##Matrícula: 20190023610
# ##Base de dados: gender_classification.csv
#
# Obs: Não conseguir deixar a base no google Collab, logo é necessário baixar e colocar manualmente aqui.

# %%
import math

# %% [markdown]
# # Questão 1 - Complete a tabela abaixo

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ## a) Agente comentarista de jogo
#
# Jogo escolhido: Epic Seven.
#
# Contexto do jogo:
# ![EpicSeve2.jpg](data:image/jpeg;base64,...)
#
# Epic Seven é um jogo Mobile caracterizado como RPG em turno, das diversas áreas do jogo, o agente agirá na arena global, que consiste em batalha de jogador versus jogador. Dentro da partida cada jogador controlará 4 personagens com o objetivo de derrotar os outros 4 personagens do oponente, a partida termina quando não sobrar mais personagens de um dos jogadores, dando a vitória para aquele que possui personagem(s) vivos.
#
# Cada personagem possui 3 habilidades que pode usar, elas diferem de personagem para personagem permitindo que ele executem funções diferentes. Algumas habilidades pode colocar efeitos benéficos(azul) para aliados ou maléficos(vermelho) para inimigos, esses efeitos ficam acima do personagem.
#
# - Medida de desempenho:
#
# A principal medida seria na velocidade do repasse das informações importantes que estão acontecendo na tela em relação ao momento que elas aconteceram.
#
# Na questão do jogo, ele deve informar todos os efeitos benéficos e maléficos que estão ativos no momento e quais personagem estão afetados. As habilidades disponiveis e as que estão em tempo de recarga. Informar dano causado, se for usado uma habilidade de dano, e quem sofreu, e consequentemente o estado do personagem, porcentagem de vida que está no momento atual.
#
# - Ambiente:
#
# Como dito no contexto do jogo, o ambiente seria virtual, celular ou em um computador com um emulador de celular. Logo o sistema deve, por meio do que está acontecendo na tela, informar as informações importantes. Assim, vai ter um dispositivo que terá ascesso ao jogo para poder entrar na partida que está acontecendo como um espectador.
#
# - Atuadores:
#
# Como nesse agente ele deve fazer a leitura da que está acontecendo na tela, ele deve está em um celular ou em um computador. Logo, seu atuador deve ser a máquina na qual ele está obtendo as informações, um computador ou celular.
#
# - Sensores:
#
# Para os sensores desse agente, ele deverá obter informações da partida por meio da imagem do que está acontecendo, logo captar vídeo.
#
# ## b) Agente sugestor de vinho
#
# - Medida de desempenho:
#
# Como o agente tem a principal função de sugerir vinhos, nada mais justo do que o método de avaliação dele seja baseado no feedback da pessoas que provam do vinho que o agente sugeriu. Sua locomoção se dá dentro do restaurante, logo precisa se segura, para não bater em mesas e nas pessoas.
#
# - Ambiente:
#
# O local que o agente poderá agir seria no resturante, assim, recebendo o pedido, dos clientes, com os detalhes do vinho desejado.
#
# - Atuadores:
#
# O Agente é um robô que vai até a mesa, assim, precisa de um corpo que possibilita seu movimento até a mesa que o chamou. Acelerar, frear na frente do cliente são alguns exemplos de suas funcionalidades. Comunicar com o cliente informando qual vinho foi escolhido pelas caractrísticas informadas, e finalizar o pedido.
#
# - Sensores:
#
# Sensores de proximidade se faz de grande necessidade para não bater nas mesas e nos clientes do restaurante. Um Sensor ao toque para que o cliente possa escolher as características do vinho na tela do agente.
#
# ## c) Agente treinador de time
#
# - Medida de desempenho:
#
# Como o agente tem a função de treinar um time, sua medida de desempenho seria de como o time treinado por ele está se saindo nas partidas.
#
# - Ambiente:
#
# O local que o agente agirá será no time de voleyball, ele terá o papel de auxiliar nos treinos da equipe e analisar pontos importantes durante um partida, como time está se saindo, onde este está errando mais, quais posições estão precisando trabalhar mais. Logo, quadra esportiva e sala de treinamento.
#
# - Atuadores:
#
# Exibir estratégias para serem seguidas durante o jogo, por onde é melhor atacar, qual posição deve tomar cuidado. Todas essas informações mostradas por um tela de exibição.
#
# - Sensores:
#
# Uma câmera para pegar as informações de cada integrante do time em campo, teclado para que o treinado possar colocar informações importantes.

# %% [markdown]
# # Questão 2 - Tipos de aprendizado de máquinas

# %%
import pandas as pd

df = pd.read_csv('gender_classification.csv', delimiter=",")
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %% [markdown]
# Os quatro tipos de aprendizados de máquinas são:
# - Aprendizagem supervisionada
# - Aprendizagem não supervisionada
# - Aprendizagem semi-supervisionada
# - Aprendizagem por reforço
#
# ## A aprendizagem supervisonada:
#
# A aprendizagem supervisonada consiste em que o sistema recebe dados já rotulados e a saída já é fornecida. Podemos exemplificar esse método como se fosse ensinando matemática para uma criança, onde fornecemos a informação que 2 + 2 = 4, todas as informações sobre o problema é fornecida para que ele possa predeterminar conslusões. Assim, outras somas ela vai conseguir predeterminar formas para se chegar na conclusão. Ou seja, a máquina poderá determinar de forma correta os novos exemplos não rotulados.
#
# Assim, usando a base de dados acima, para o contexto da aprendizagem supervisionada é usada uma porcentagem de mais ou menos 70% de dados, para treinar a máquina com os dados já rotulados, informando suas classes e qual a saída para um determinado conjunto é male ou female. E os outros 30% serve para verificar como que está o desempenho da máquina.
#
# ## A apredizagem não supervisionada
#
# A apredizagem não supervisionada diferente da supersioada, consiste em que o sistema recebe dados não rotulados, predetermindados ou qualquer correlação entre a entrada e a saída. Logo o algoritmo deve procurar uma solução por ele mesmo e não possui dados de referência armazendado. Podemos exemplificar esse método como se fosse uma pessoal que nunca viu futebol ou teve qualquer informação sobre ele, e ela deverá entender o que está acontecendo apenas pelo que está vendo. Logo, a máquina deve observar se encontra algum tipo de padrão entre os dados fornecidos e os agrupar.
#
# Assim, usando a base de dados acima, para o contexto da aprendizagem não supervisionada, é passado os dados para a máquina sem rótulos, ele não vai saber o que cada dado significa, mas vai saber que para este caso ele precisa separar os dados em 2 categorias. A máquina deve procurar padrões nesses dados e os agrupa-los para em duas categorias.
#
# ## A aprendizagem semi-supervisionada
#
# A aprendizagem semi-supervisionada é considerada um método intermediário entre a supervisionada e a não supervisionada. Isso por que ela trabalha com informações rotuladas e não rotuladas, ela aprende com os dados rotulados para depois rotular os dados incompletos buscando padrões.
#
# Assim, usando a base de dados acima, para o contexto de aprendizagem semi-supervisionada, a base terá rotulos faltando, logo será necessário rodar primeiramento em um contexto não supervisionado para que haja o agrupamento de padrões de dados. Isso permitir que os dados rotulados e não rotulados se agrupem de acordo com suas similiaridades nas duas classes de Female e Male, e assim assumimos que esses dados não rotulados sejam classificados de acordo com a classe que estão dentro.
#
# ## A aprendizagem por reforço
#
# A aprendizagem por reforço consiste em que o sistema aprenda por meio da tentativa e erro. Nesse método o agente não precisa ser informados de dados previamente para ser treinado como nos outros casos, ele aprende interagindo com o seu ambiente. Geralmente ele funciona com um sistema de recompensa, que toda vez que a máquina atinge um resultado certo ela ganha uma recompensa e quando atinge um resultado errado ela sofre uma penalidade, logo ela busca maximizar os ganhos e minimizar as perdas, pois essa é a medida de desempenho para verificar se suas ações está certa ou não.
#
# Assim, usar esse método para a base acima é bastante complicado, pois a aprendizagem por reforço tem maior utilização no âmbito mais prático, em contexto de jogos ou em resolver desafios(labirinto). Logo para exemplificar esse tipo de aprendizagem, vamos trazer o exemplo do jogo do dinossauro do goole de quando a não há internet. Nesse jogo as ações possíveis são de pular e abaixar, a máquina e informada disso e que sua medida de desempenho são os pontos obtidos, logo ela vai buscar ações que aumentem esses pontos. Conforme o jogo vai acontecendo ela percebe que ao bater no cacto ou em outro dinossauro, ela perde pontos. Assim, faz com que ela busque formas de evita-los, sendo pulando ou agachando até que ela aprende por tentativa e erro.

# %% [markdown]
# # Questão 3 - utilize o método K vizinhos mais próximos na base escolhida na questão anterior

# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
import plotly.express as px
import math
from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split


import seaborn as sns
sns.set()

# %%
df = pd.read_csv('gender_classification.csv', delimiter=",")
df

# %% [markdown]
# ## a) Aplique processos de pré-processamento e os necessários para execução do método K-NN.

# %%
#verificar se há dados faltosos
print('Valores faltantes:\n', df.isnull().sum())
# Out:
# Valores faltantes:
#  long_hair                    0
# forehead_width_cm            0
# forehead_height_cm           0
# nose_wide                    0
# nose_long                    0
# lips_thin                    0
# distance_nose_to_lip_long    0
# gender                       0
# dtype: int64

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
#verificar cada classe de forma geral
df.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
#verificar se há valores duplicados
print('Valores duplicados:\n', df.duplicated())
# Out:
# Valores duplicados:
#  0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4996     True
# 4997     True
# 4998     True
# 4999     True
# 5000     True
# Length: 5001, dtype: bool

# %%
df = df.drop_duplicates(keep=False)
df
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 1             0               14.0                 5.4          0          0
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# 5             1               13.0                 6.8          1          1
# 7             0               13.0                 5.2          0          0
# ...         ...                ...                 ...        ...        ...
# 4986          1               11.7                 6.1          1          1
# 4990          1               12.6                 5.7          0          0
# 4992          1               14.1                 7.0          1          1
# 4993          1               11.6                 5.9          0          0
# 4995          1               12.3                 6.9          0          1
#
# ...

# %%
x = df['gender'].value_counts() 
x/len(df)
# Out:
# Male      0.584615
# Female    0.415385
# Name: gender, dtype: float64

# %%
df.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  2275.000000        2275.000000         2275.000000  2275.000000
# mean      0.776703          13.220835            5.979429     0.555165
# std       0.416547           1.123220            0.553098     0.497057
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.300000            5.500000     0.000000
# 50%       1.000000          13.200000            6.000000     1.000000
# 75%       1.000000          14.100000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  2275.000000  2275.000000                2275.000000
# mean      0.586374     0.564835                   0.568791
# std       0.492591     0.495888                   0.495354
# min       0.000000     0.000000                   0.000000
# ...

# %% [markdown]
# ##Verificamos que nos dados não a nenhum tipo de outiler ou qualquer dado faltoso. Mas na verificação de duplicatas na base, foi observado a existência de elementos duplicados, retiramos esses elementos com retorno de True pela função deixando com 2275 elementos na base. Agora vamos transformar todos os atributos de qualitativos para quantitativos para podermos Escalar os dados em um periodo só.

# %%
le = preprocessing.LabelEncoder() #transforma atributos qualitativos em quantitativos
for column in df.columns:
    if df[column].dtypes == 'object':
        df[column] = le.fit_transform(df[column])
        
print(df)
#GENDER : FEMALE = 0; MALE = 1
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 1             0               14.0                 5.4          0          0
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# 5             1               13.0                 6.8          1          1
# 7             0               13.0                 5.2          0          0
# ...         ...                ...                 ...        ...        ...
# 4986          1               11.7                 6.1          1          1
# 4990          1               12.6                 5.7          0          0
# 4992          1               14.1                 7.0          1          1
# 4993          1               11.6                 5.9          0          0
# 4995          1               12.3                 6.9          0          1
#
# ...

# %%
x = df['gender'].value_counts();
x/len(df)
# Out:
# 1    0.584615
# 0    0.415385
# Name: gender, dtype: float64

# %%
#Escalando os dados
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()

X =  pd.DataFrame(sc_X.fit_transform(df.drop(["gender"],axis = 1),),
        columns=['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide', 'nose_long',
       'lips_thin', 'distance_nose_to_lip_long'])

y = df.gender

X.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0  -1.865033           0.693841           -1.047835  -1.117150  -1.190647
# 1  -1.865033           1.050038            0.218041  -1.117150   0.839879
# 2   0.536184           0.248594           -0.143638  -1.117150  -1.190647
# 3   0.536184          -0.196652            1.483916   0.895135   0.839879
# 4  -1.865033          -0.196652           -1.409514  -1.117150  -1.190647
#
#    lips_thin  distance_nose_to_lip_long
# 0   0.877740                  -1.148504
# 1   0.877740                   0.870698
# 2  -1.139289                  -1.148504
# 3   0.877740                   0.870698
# 4  -1.139289                  -1.148504

# %% [markdown]
# ### Se tiver valores com escalas de valores muito diferentes pode gerar valores errôneos, pois a distância calculado pelo algoritmos de distâncias são influenciados por essa descrepância. Assim, é bom deixar os valores dentro de um período.

# %% [markdown]
# ## b) Aplique correlação ou PCA e seleciona um número menor de atributos com esses métodos e justifique sua decisão.

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_ee58c_row0_col0, #T_ee58c_row1_col1, #T_ee58c_row2_col2, #T_ee58c_row3_col3, #T_ee58c_row4_col4, #T_ee58c_row5_col5, #T_ee58c_row6_col6, #T_ee58c_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ee58c_row0_col1, #T_ee58c_row0_col2, #T_ee58c_row0_col3, #T_ee58c_row0_col4, #T_ee58c_row0_col5, #T_ee58c_row0_col6, #T_ee58c_row0_col7, #T_ee58c_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ee58c_row1_col2, #T_ee58c_row5_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_ee58c_row1_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_ee58c_row1_col4, #T_ee58c_row2_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_ee58c_row1_col5, #T_ee58c_row6_col4 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_ee58c_row1_col6, #T_ee58c_row5_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ee58c_row1_col7 {
#   background-color: #9dbdff;
# ...

# %%
plt.figure(figsize=(12,10))  
p=sns.heatmap(df.corr(), annot=True,cmap ='RdYlGn')

# %% [markdown]
# ## Após o pré-processamento, verificamos por meio da correlação que os atributos, antes do escalamento, estão bem diversificados, possuindo uma correlação mínima, apenas alguns dados com gênero estão um pouco correlacionado, mas sabemos que não há necessidade de qualquer ação. Logo, não é necessário que se retire um atributo ou junte dois atributos para os próximos passos.

# %% [markdown]
# ## c) Escolha 5 valores de K e mostre os resultados (escolha 3 métricas de avaliação e mostre a matriz de confusão) e explique os resultados encontrados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

from sklearn import cluster, neighbors, svm, metrics, preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')

# %%
# Fazendo a divisão dos dados para treinamento e testes
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1, stratify=y)

test_scores = []
train_scores = []

for i in range(1,15):# Fazendo os teste de pontuação para 0 < k > 15 e vendo suas pontuações

    knn = KNeighborsClassifier(i)
    knn.fit(X_train,y_train)
    
    train_scores.append(knn.score(X_train,y_train))
    test_scores.append(knn.score(X_test,y_test))

# %%
# A melhor Pontuação que vem pelo testes dos dados que usamos no treinamento com diferentes K
max_train_score = max(train_scores)
train_scores_ind = [i for i, v in enumerate(train_scores) if v == max_train_score]
print('Max train score {} % and k = {}'.format(max_train_score*100,list(map(lambda x: x+1, train_scores_ind))))
# Out:
# Max train score 99.74874371859298 % and k = [1]

# %%
# A melhor Pontuação que vem pelo teste dos dados, que dividimos no ínicio, para teste com diferentes K
max_test_score = max(test_scores)
test_scores_ind = [i for i, v in enumerate(test_scores) if v == max_test_score]
print('Max test score {} % and k = {}'.format(max_test_score*100,list(map(lambda x: x+1, test_scores_ind))))
# Out:
# Max test score 92.97218155197658 % and k = [7]

# %%
plt.figure(figsize=(12,5))#vizualizar as pontuações no gráfico e comparar com a pontuação de treinamento
p = sns.lineplot(range(1,15),train_scores,marker='*',label='Train Score')
p = sns.lineplot(range(1,15),test_scores,marker='o',label='Test Score')

# %%
#Verificar a taxa de erro entre 1<= k < 15
error = []

for i in range(1, 15):  
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error.append(np.mean(pred_i != y_test))

plt.figure(figsize=(12, 6))  
plt.plot(range(1, 15), error, color='red', linestyle='dashed', marker='o', markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')  
plt.xlabel('Valor de K')  
plt.ylabel('Média de erro')
# Out:
# Text(0, 0.5, 'Média de erro')

# %% [markdown]
# ###Pelas informações observadas pelos gráficos, o melhor K para o nosso modelo seria o 7, ele que tem a menor taxa de erro, e nos testes ele que tem a melhor taxa de acerto com o periodo de 1 <= k < 15. Ou seja, sua acurácia é de aproximadamente de 0.93, o qual é uma acurácia bem alta e mehlor do que os outros K's desse período.

# %% [markdown]
# ### K = 1

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=1, algorithm="auto")
knn.fit(X_train, y_train)
resultKNN = knn.predict(X_test)

print("\nK-NN: K = 1")
matrizConfusao = metrics.confusion_matrix(y_test, resultKNN)

print(classification_report(y_test, resultKNN))
print("\n Female = 0| Male = 1")
pd.crosstab(y_test, resultKNN, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# K-NN: K = 1
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.89       284
#            1       0.91      0.93      0.92       399
#
#     accuracy                           0.91       683
#    macro avg       0.91      0.90      0.90       683
# weighted avg       0.91      0.91      0.91       683
#
#
#  Female = 0| Male = 1
# Predicted    0    1  All
# True
# 0          248   36  284
# 1           28  371  399
# All        276  407  683

# %% [markdown]
# ### K = 3

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=3, algorithm="auto")
knn.fit(X_train, y_train)
resultKNN = knn.predict(X_test)

print("\nK-NN: K = 3")
matrizConfusao = metrics.confusion_matrix(y_test, resultKNN)

print(classification_report(y_test, resultKNN))
print("\n Female = 0| Male = 1")
pd.crosstab(y_test, resultKNN, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# K-NN: K = 3
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90       284
#            1       0.93      0.93      0.93       399
#
#     accuracy                           0.92       683
#    macro avg       0.91      0.91      0.91       683
# weighted avg       0.92      0.92      0.92       683
#
#
#  Female = 0| Male = 1
# Predicted    0    1  All
# True
# 0          255   29  284
# 1           29  370  399
# All        284  399  683

# %% [markdown]
# ### K = 5

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=5, algorithm="auto")
knn.fit(X_train, y_train)
resultKNN = knn.predict(X_test)

print("\nK-NN: K = 5")
matrizConfusao = metrics.confusion_matrix(y_test, resultKNN)

print(classification_report(y_test, resultKNN))
print("\n Female = 0| Male = 1")
pd.crosstab(y_test, resultKNN, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# K-NN: K = 5
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       284
#            1       0.94      0.93      0.93       399
#
#     accuracy                           0.92       683
#    macro avg       0.92      0.92      0.92       683
# weighted avg       0.92      0.92      0.92       683
#
#
#  Female = 0| Male = 1
# Predicted    0    1  All
# True
# 0          259   25  284
# 1           27  372  399
# All        286  397  683

# %% [markdown]
# ### K = 9

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=9, algorithm="auto")
knn.fit(X_train, y_train)
resultKNN = knn.predict(X_test)

print("\nK-NN: K = 9")
matrizConfusao = metrics.confusion_matrix(y_test, resultKNN)

print(classification_report(y_test, resultKNN))
print("\n Female = 0| Male = 1")
pd.crosstab(y_test, resultKNN, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# K-NN: K = 9
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91       284
#            1       0.94      0.92      0.93       399
#
#     accuracy                           0.92       683
#    macro avg       0.92      0.92      0.92       683
# weighted avg       0.92      0.92      0.92       683
#
#
#  Female = 0| Male = 1
# Predicted    0    1  All
# True
# 0          262   22  284
# 1           32  367  399
# All        294  389  683

# %% [markdown]
# ### K = 7

# %%
knn = neighbors.KNeighborsClassifier(n_neighbors=7, algorithm="auto")
knn.fit(X_train, y_train)
resultKNN = knn.predict(X_test)

print("\nK-NN: K = 7")
matrizConfusao = metrics.confusion_matrix(y_test, resultKNN)

print(classification_report(y_test, resultKNN))
print("\n Female = 0| Male = 1")
pd.crosstab(y_test, resultKNN, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# K-NN: K = 7
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       284
#            1       0.95      0.93      0.94       399
#
#     accuracy                           0.93       683
#    macro avg       0.93      0.93      0.93       683
# weighted avg       0.93      0.93      0.93       683
#
#
#  Female = 0| Male = 1
# Predicted    0    1  All
# True
# 0          263   21  284
# 1           27  372  399
# All        290  393  683

# %% [markdown]
# Por meio das métricas e da matriz confusão dos K's escolhidos, podemos verificar qual deles é o melhor para ser escolhido para o algoritmo que terá maior probabilidade de se aproximar do ideal de classificação. A diferença de cada K para o outro é bem pequena, quase não existe, porêm para escolher 1 o k=7 é o melhor.

# %% [markdown]
# ## d) Escolha 2 métricas de similaridade (diferentes distâncias ou outras métricas - correlação, por exemplo) para definir o(s) vizinho(s) mais próximos e explique os resultados encontrados.

# %%
knn = neighbors.KNeighborsClassifier(p=1, n_neighbors=7, algorithm="auto")
knn.fit(X_train, y_train)
resultKNN = knn.predict(X_test)

print("\nK-NN: K = 7 - Distância = Manhattan")
matrizConfusao = metrics.confusion_matrix(y_test, resultKNN)

print(classification_report(y_test, resultKNN))
print("\n Female = 0| Male = 1")
pd.crosstab(y_test, resultKNN, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# K-NN: K = 7 - Distância = Manhattan
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       284
#            1       0.95      0.93      0.94       399
#
#     accuracy                           0.93       683
#    macro avg       0.93      0.93      0.93       683
# weighted avg       0.93      0.93      0.93       683
#
#
#  Female = 0| Male = 1
# Predicted    0    1  All
# True
# 0          266   18  284
# 1           27  372  399
# All        293  390  683

# %%
knn = neighbors.KNeighborsClassifier(p=2, n_neighbors=7, algorithm="auto")
knn.fit(X_train, y_train)
resultKNN = knn.predict(X_test)

print("\nK-NN: K = 7 - Distância = Euclediana")
matrizConfusao = metrics.confusion_matrix(y_test, resultKNN)

print(classification_report(y_test, resultKNN))
print("\n Female = 0| Male = 1")
pd.crosstab(y_test, resultKNN, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# K-NN: K = 7 - Distância = Euclediana
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92       284
#            1       0.95      0.93      0.94       399
#
#     accuracy                           0.93       683
#    macro avg       0.93      0.93      0.93       683
# weighted avg       0.93      0.93      0.93       683
#
#
#  Female = 0| Male = 1
# Predicted    0    1  All
# True
# 0          263   21  284
# 1           27  372  399
# All        290  393  683

# %% [markdown]
# A melhor distância para este K = 7, seria o da distância Manhattan. Podemos verificar isso pelas métricas de avaliação informadas, a diferença nesses casos é bem pequena, mas ela existe. Seria bem na predição da classe Female, o qual, por meio de Manhattan ela consegue predizer melhor verdadeiros do que a distância Euclediana para este caso.

# %% [markdown]
# ## e) Melhor K e melhor distância e testar com o conjunto de atributos do item 2.

# %% [markdown]
# - K = 7
# - Distância = Manhattan
# - Conjunto de dados do item 2 não houve nenhuma mudança em relação aos atributos.

# %%
knn = neighbors.KNeighborsClassifier(p=1, n_neighbors=7, algorithm="auto")
knn.fit(X_train, y_train)
resultKNN = knn.predict(X_test)

print("\nK-NN: K = 7 - Distância = Manhattan")
matrizConfusao = metrics.confusion_matrix(y_test, resultKNN)

print(classification_report(y_test, resultKNN))
print("\n Female = 0| Male = 1")
pd.crosstab(y_test, resultKNN, rownames=['True'], colnames=['Predicted'], margins=True)
# Out:
# K-NN: K = 7 - Distância = Manhattan
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       284
#            1       0.95      0.93      0.94       399
#
#     accuracy                           0.93       683
#    macro avg       0.93      0.93      0.93       683
# weighted avg       0.93      0.93      0.93       683
#
#
#  Female = 0| Male = 1
# Predicted    0    1  All
# True
# 0          266   18  284
# 1           27  372  399
# All        293  390  683

# %% [markdown]
# # Questão 4 - Considerando a matriz de confusão, informe os valores das métricas

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Apartir da tabela temos que:
# - Acurácia: 0,909
# - Precisão: 0,727
# - Sensibilidade: 0,786
# - Especificidade: 0,963
# - Medida F1: 0,755
# - Coeficiente de Matthews: 0,706
# - AUC: 0,875
#
# O problema dessa base de dados é que a classe Manga tem maior representatividade que as demais classes, ou seja, um problema de desbalanceamento de classes. Isso faz com que o modelo fique induzido em prever objetos mais para a classe Manga do que para as outras classes, podendo acarretar em problemas de na construção de modelos e na geração de previsões. Uma forma de resolver o problema dessa base é utilizar Undersamplim, consiste em reduzir o número de observações da classe majoritária a fim de diminuir essa diferença entre elas. Agora, pode ser feito de duas maneiras, a primeira é com Random Undersampling que é feita uma retirada aleatória da classe, que pode ocasionar um perda grave de informação. E a outra é utilização de unir duas ou mais observações da classe, que ocasiona numa menor perda de informação, que algoritmos de clusterização clássicos podem ser usados, como o KNN.

# %%
acuracia = (70+67+55+1000)/(70+10+5+5+20+67+30+4+5+3+55+2+5+20+10+1000)
precisao = (70/(70+20+5+5) + 67/(67+10+3+20) + 55/(55+5+30+10) + 1000/(1000+5+4+2))/4
sensibilidade = (70/(70+10+5+5) + 67/(67+20+30+4) + 55/(55+5+3+2) + 1000/(1000+5+20+10))/4
especificidade = ((67+55+1000)/(67+55+1000+20+5+5) + (70+55+1000)/(70+55+1000+10+3+20) + (70+67+1000)/(70+67+1000+5+30+10) + (70+67+55)/(70+67+55+5+4+2))/4
f1 = 2 * ((precisao * sensibilidade)/(precisao + sensibilidade))

phi1 = ((70*(67+55+1000))-(20+5+5)*(10+5+5))/(math.sqrt((70+20+5+5)*(70+10+5+5)*(67+55+1000+20+5+5)*(67+55+1000+10+5+5)))
phi2 = ((67*(70+55+1000))-(10+3+20)*(20+30+4))/(math.sqrt((67+10+3+20)*(67+20+30+4)*(70+55+1000+10+3+20)*(70+55+1000+20+30+4)))
phi3 = ((55*(70+67+1000))-(5+30+10)*(5+3+2))/(math.sqrt((55+5+30+10)*(55+5+3+2)*(70+67+1000+5+30+10)*(70+67+1000+5+3+2)))
phi4 = ((1000*(70+67+55))-(5+4+2)*(5+20+10))/(math.sqrt((1000+5+4+2)*(1000+5+20+10)*(70+67+55+5+4+2)*(70+67+55+5+20+10)))
phi = (phi1 + phi2 + phi3 + phi4)/4

tvp = sensibilidade
tfp = (1-especificidade)

print("tvp: %0.3f\n" % (tvp))
print("tfp: %0.3f\n" % (tfp))

x = np.array([0, tvp, 1])
y = np.array([0, tfp, 1])

print("Acuracia: %0.3f\n" % acuracia)
print("Precisão: %0.3f\n" % precisao)
print("Sensibilidade: %0.3f\n" % sensibilidade)
print("Especificidade: %0.3f\n" % especificidade)
print("Medida F1: %0.3f\n" % f1)
print("Coeficiente de Mattews: %0.3f\n" % phi)
print("AUC: %0.3f\n" % (np.trapz(x,y)))
# Out:
# tvp: 0.786
#
# tfp: 0.037
#
# Acuracia: 0.909
#
# Precisão: 0.727
#
# Sensibilidade: 0.786
#
# Especificidade: 0.963
#
# Medida F1: 0.755
#
# Coeficiente de Mattews: 0.706
#
# AUC: 0.875

# %% [markdown]
# # Questão 5 - Elabore uma pergunta e responda sobre "Preconceito e Inteligência Artificial", refletindo aspectos importantes do método que uma pessoa engenheiro de dados/cientista de dados deve conhecer e se preocupar garantindo ética nos modelos criados.

# %% [markdown]
# ## De que forma o preconteito se envolve com a inteligência artificial, cite exemplos se possível de casos de que isso aconteceu, e como evita-los.
#
# Como a principal função da Inteligência Artificial é aprender com os dados que são fornecidos à ela, é possível que ela adquira certos preconceitos devido aos dados de entrada. Logo, adquirindo potencial para discriminar certos grupos, ser induzida para tomar ações questionáveis, entre outras coisas.
#
# Exemplos de casos o qual a IA adquiriu certo preconceito, podemos citar o caso da @TayandYou, uma inteligência artificial criada por um equipe da Microsoft com intuito de fazer um experimento na compreensão das conversas. Ela aprendia com intereção da IA com os usuário da rede social, assim, muitos usuários começaram a publicar mensagem preconceituosas e ela absorveu isso, com o tempo ela começou a replicar esse tipo mensagem.
#
# Outro exemplo foi de um sistema de IA que buscava prever o "índice de reincidência" dos acusados. Tem como a principal de função de avaliar a chance do acusado cometer outro crime, se a chance for alta ele tomaria uma pena maior. Ao analisar essa ferramena, descobriu-se que réus afro-americanos eram mais propensos a serem classificados incorretamente, com maior probabilidade de reincidirem.
#
# Assim, podemos inferir que se a inteligência artificial aprende a ter um raciocínio parecido com o humano, ela também pode adquirir os nossos preconceitos. Para evitar esse tipo de comportamento anormal seja absorvido pela IA devemos tomar certas medidas. Os cientistas de dados deve examinar cuidadosamente os dados que IA está recebendo, usar fonte de dados limpas. É necessário que nossos projetos possuem conceitos de éticas.
